# %%
numeric_stats = ['derived_fg', 'derived_ft', 'G', 'GS', 'MP', 'FG', 'FGA', 'FG%', '3P', '3PA', '3P%', '2P', '2PA', '2P%', 'eFG%', 'FT', 'FTA', 'FT%', 'ORB', 'DRB', 'TRB', 'AST', 'STL', 'BLK', 'TOV', 'PF', 'PTS']
fantasy_stats = ['derived_fg', 'derived_ft','TRB', 'AST', 'STL', 'BLK', 'TOV', '3P', 'PTS']
negative_stats = ['FTA', 'TOV', 'FGA']

# %%
# Import stats CSV
import pandas as pd

arr = pd.read_csv('nba_stats.csv')
arr['Player'] = arr['Player'].transform(lambda name: name.split('\\')[0].strip())
arr = arr.drop(['Rk', 'GS', 'Age', 'Pos', 'FG%', 'FT%', '2P%', 'eFG%', '3PA', '3P%', '2P', '2PA', 'Tm'], axis=1)
arr = arr.groupby(arr['Player']).sum()
arr['FT%'] = arr['FT'] * 100 / arr['FTA']
arr['FG%'] = arr['FG'] * 100 / arr['FGA']
arr['derived_fg'] = arr['FG'] * (arr['FG%'] - arr['FG%'].mean())
arr['derived_ft'] = arr['FT'] * (arr['FT%'] - arr['FT%'].mean())
arr[['TRB', 'AST', 'STL', 'BLK', 'TOV', '3P', 'PTS']] = arr[['TRB', 'AST', 'STL', 'BLK', 'TOV', '3P', 'PTS']].div(arr['G'], axis=0)

# %%
# Import average draft values TSV
raw_draft_values = pd.read_csv('draft_values.tsv', sep='\t')
raw_draft_values
def transform_name(name):
    notes_loc = name.find('Notes')
    if notes_loc > -1:
        name = name[notes_loc+5:]
    note_loc = name.find('Note')
    if note_loc > -1:
        name = name[note_loc+4:]
    return ' '.join(name.split()[0:2])

def transform_average(val):
    val = val[1:]
    try:
        num_val = float(val)
        return num_val
    except ValueError:
        return 0

raw_draft_values['Name'] = raw_draft_values['Name'].transform(transform_name)
raw_draft_values['Average'] = raw_draft_values['Average'].transform(transform_average)
raw_draft_values = raw_draft_values.set_index('Name')

# %%
arr = arr.join(raw_draft_values[['Average']])

# %%
transform_functions = {}
for col in arr.iteritems():
    stat = col[0]
    if stat in numeric_stats:
        std_dev = arr[stat].std()
        mean = arr[stat].mean()
        if stat in negative_stats:
            std_dev=std_dev*-1
        transform_functions[stat] = lambda val,mean=mean,std_dev=std_dev: (val-mean)*1000/std_dev
    else:
        transform_functions[stat] = lambda val: val
arr = arr.dropna()
z_scores = arr.transform(transform_functions)

# %%
z_scores['zach_points'] = z_scores[fantasy_stats].sum(axis=1)
z_scores = z_scores[z_scores.Average != 0]
z_scores['points_per_dollar'] = (z_scores['zach_points'])/z_scores['Average']
top_players = z_scores.nlargest(200, 'zach_points')[fantasy_stats+['zach_points', 'Average', 'points_per_dollar']]

# %%
top_players['Name'] = top_players.index
ax = top_players.plot.scatter(x=['zach_points'], y=['Average'])
def label_point(x, y, val, ax):
    a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
    for i, point in a.iterrows():
        ax.text(point['x'], point['y'], str(point['val']))

label_point(top_players.zach_points, top_players.Average, top_players.Name, ax)

# %%
#Value of assists
#fantasy_stats = ['derived_fg', 'derived_ft','TRB', 'AST', 'STL', 'BLK', 'TOV', '3P', 'PTS']
top_players['asttov'] = top_players['AST'] - top_players['TOV']
ax = top_players.plot.scatter(x=['zach_points'], y=['Average'])
# def label_point(x, y, val, ax):
#     a = pd.concat({'x': x, 'y': y, 'val': val}, axis=1)
#     for i, point in a.iterrows():
#         ax.text(point['x'], point['y'], str(point['val']))

# label_point(top_players.zach_points, top_players.asttov, top_players.Name, ax)

# %%
print(top_players.to_json(orient='index'))
# Out:
# {"James Harden":{"derived_fg":-373.4704411629,"derived_ft":6553.2551862866,"TRB":1180.429507658,"AST":3181.6420423019,"STL":3040.6400686295,"BLK":1176.2138091778,"TOV":-4145.1060937061,"3P":4039.085508176,"PTS":4020.5849092873,"zach_points":18673.2744966482,"Average":73.1,"points_per_dollar":255.4483515273,"Name":"James Harden","asttov":7326.748136008},"Anthony Davis":{"derived_fg":1834.9243390769,"derived_ft":3414.9062937367,"TRB":2287.9007561989,"AST":740.9467558743,"STL":2116.9165474282,"BLK":4622.2946619291,"TOV":-1656.6662376053,"3P":260.3671550095,"PTS":2726.8415900621,"zach_points":16348.4318617105,"Average":73.5,"points_per_dollar":222.427644377,"Name":"Anthony Davis","asttov":2397.6129934796},"Damian Lillard":{"derived_fg":422.0151503846,"derived_ft":5126.0043655942,"TRB":271.1994135704,"AST":3465.7115287012,"STL":1101.8349671906,"BLK":-152.3219137572,"TOV":-2210.8187236915,"3P":3681.5649954662,"PTS":3334.8124227062,"zach_points":15040.0022061647,"Average":64.9,"points_per_dollar":231.741174209,"Name":"Damian Lillard","asttov":5676.5302523927},"Kawhi Leonard":{"derived_fg":574.2259358448,"derived_ft":3835.89921632,"TRB":1379.4659858643,"AST":1697.3936076521,"STL":2962.8071749479,"BLK":442.0230149243,"TOV":-1815.0134015761,"3P":1424.1980625396,"PTS":2879.6459705401,"zach_points":13380.6455670568,"Average":49.5,"points_per_dollar":270.3160720618,"Name":"Kawhi Leonard","asttov":3512.4070092282},"Hassan Whiteside":{"derived_fg":4876.2107514088,"derived_ft":-1027.9751329203,"TRB":3981.1790447847,"AST":-428.2599400127,"STL":-574.9748231451,"BLK":6119.9813367946,"TOV":-813.8298047446,"3P":-1026.0641606138,"PTS":1066.8760513511,"zach_points":12173.1433229027,"Average":11.3,"points_per_dollar":1077.2693206109,"Name":"Hassan Whiteside","asttov":385.5698647319},"Karl-Anthony Towns":{"derived_fg":1061.5081686597,"derived_ft":507.1768775549,"TRB":2889.8970405405,"AST":1390.6611939885,"STL":808.2603527312,"BLK":1944.8666203045,"TOV":-2458.3356373112,"3P":2707.8959060801,"PTS":2783.4122084627,"zach_points":11635.3427310107,"Average":65.5,"points_per_dollar":177.6388203208,"Name":"Karl-Anthony Towns","asttov":3848.9968312997},"Devin Booker":{"derived_fg":1528.7297963252,"derived_ft":6412.1189940941,"TRB":246.9457508472,"AST":2605.9355854731,"STL":202.7627104087,"BLK":-336.6901365318,"TOV":-3223.0049108769,"3P":1256.4919831167,"PTS":2808.0804704506,"zach_points":11501.370243307,"Average":43.7,"points_per_dollar":263.1892504189,"Name":"Devin Booker","asttov":5828.94049635},"John Collins":{"derived_fg":3007.5295615638,"derived_ft":283.7998490209,"TRB":2626.4305109977,"AST":-258.5550777726,"STL":342.6265847472,"BLK":2936.4079159584,"TOV":-860.3294503142,"3P":584.7039604611,"PTS":2018.641390024,"zach_points":10681.2552446863,"Average":41.6,"points_per_dollar":256.7609433819,"Name":"John Collins","asttov":601.7743725416},"Rudy Gobert":{"derived_fg":6158.6384719473,"derived_ft":-2597.7213246975,"TRB":3966.3162637424,"AST":-246.1466089739,"STL":327.4239897104,"BLK":3845.1471811454,"TOV":-960.6879290576,"3P":-1095.7833403067,"PTS":998.7228157606,"zach_points":10395.9095192705,"Average":30.4,"points_per_dollar":341.9707078707,"Name":"Rudy Gobert","asttov":714.5413200837},"Trae Young":{"derived_fg":-595.6569140112,"derived_ft":4297.0086790591,"TRB":249.8247827532,"AST":4204.6965627151,"STL":1158.499185055,"BLK":-636.2884985407,"TOV":-4494.5572256319,"3P":2894.1872141999,"PTS":3282.0101098559,"zach_points":10359.7238954545,"Average":57.4,"points_per_dollar":180.4829946943,"Name":"Trae Young","asttov":8699.2537883471},"Bradley Beal":{"derived_fg":91.0010649492,"derived_ft":2823.854264036,"TRB":248.0569561443,"AST":2364.017806022,"STL":1563.1015827885,"BLK":17.4909230089,"TOV":-2775.423374356,"3P":2387.1177855784,"PTS":3424.9443934322,"zach_points":10144.1614016036,"Average":47.5,"points_per_dollar":213.5612926653,"Name":"Bradley Beal","asttov":5139.441180378},"Giannis Antetokounmpo":{"derived_fg":4673.3863311692,"derived_ft":-3839.5232783566,"TRB ...
